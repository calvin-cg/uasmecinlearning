# %% [markdown]
# # CONVERT TO RGB IMAGE

# %%
import cv2
import scipy.misc
import numpy as np
from PIL import Image

# %%
def get_rbg_from_lab(gray_imgs, ab_imgs, n = 10):
    imgs = np.zeros((n, 224, 224, 3))
    imgs[:, :, :, 0] = gray_imgs[0:n:]
    imgs[:, :, :, 1:] = ab_imgs[0:n:]
    
    imgs = imgs.astype("uint8")
    
    imgs_ = []
    for i in range(0, n):
        imgs_.append(cv2.cvtColor(imgs[i], cv2.COLOR_LAB2RGB))

    imgs_ = np.array(imgs_)

    print(imgs_.shape)
    
    return imgs_

# %%
images_lab = np.load('../../Dataset/train/ab1.npy')
images_lab.append(np.load('../../Dataset/train/ab2.npy'))
#images_gray = np.load('../../Dataset/test/gray_scale.npy')

imgs_for_output = get_rbg_from_lab(gray_imgs = images_gray[20000:], ab_imgs = images_lab, n = images_lab.shape[0])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-9-20ae9237ba64> in <module>
#       5 images_gray = np.load('../../Dataset/test/gray_scale.npy')
#       6
# ----> 7 imgs_for_output = get_rbg_from_lab(gray_imgs = images_gray, ab_imgs = images_lab, n = images_lab.shape[0])
#
# <ipython-input-2-825b952f49f6> in get_rbg_from_lab(gray_imgs, ab_imgs, n)
#       1 def get_rbg_from_lab(gray_imgs, ab_imgs, n = 10):
# ----> 2     imgs = np.zeros((n, 224, 224, 3))
#       3     imgs[:, :, :, 0] = gray_imgs[0:n:]
#       4     imgs[:, :, :, 1:] = ab_imgs[0:n:]
#       5
#
# MemoryError:

# %%
print(imgs_for_output.shape)
# Out:
# (5000, 224, 224, 3)

# %%
for i in range(images_lab.shape[0]):
    img = Image.fromarray(imgs_for_output[i], 'RGB')
    img.save('output/img-{}.jpg'.format(i+20000))

# %% [markdown]
# # USING MATPLOTLIB TO DISPLAY IMAGE

# %%
import numpy as np
import matplotlib.pyplot as plt

np_im = np.load('../../Dataset/test/gray_scale.npy')

plt.imshow(np_im[2], cmap='gray')
plt.show()

# %% [markdown]
# # CONVERT TO GRAYSCALE IMAGE

# %%
import numpy as np
from PIL import Image

np_im = np.load('../../Dataset/test/gray_scale.npy')
# img.show()

# %%
print(np_im.shape)
# Out:
# (25000, 224, 224)

# %%
for i in range(np_im.shape[0]):
    img = Image.fromarray(np_im[i], 'L')
    img.save('output/gray-{}.jpg'.format(i))
